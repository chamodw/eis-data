# %%
import pandas as pd
import matplotlib.pyplot as plt

df_nh4no3_1 = pd.read_csv('/Users/chamod/Documents/projects/NitrogenSensor/usb-comm/merged/nh4no3_u1.txt')
df_nh4no3_2 = pd.read_csv('/Users/chamod/Documents/projects/NitrogenSensor/usb-comm/merged/nh4no3_u2.txt')

df_nano3 = pd.read_csv('/Users/chamod/Documents/projects/NitrogenSensor/usb-comm/merged/nano3_u.txt')
df_nano2 = pd.read_csv('/Users/chamod/Documents/projects/NitrogenSensor/usb-comm/merged/nano2_u.txt')

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
# %%html
# <style>
# .output_svg div{
#   width: 75% !important;
#   height: 30% ;
# }
# </style>
# Out:
# <style>
# .output_svg div{
#   width: 75% !important;
#   height: 30% ;
# }
# </style>

# %%
#fig, ax = plt.subplots(1, 2)

df_nh4no3_2.plot(x='freq', title = 'NH4NO3 ')
#df_nh4no3_2.plot(x='freq',  ax=ax,  )

df_nano3.plot(x='freq', title='NaNO3',)
df_nano2.plot(x='freq', title='NaNO2', )
# Out:
# <AxesSubplot:title={'center':'NaNO2'}, xlabel='freq'>

# %%
comp = ' 0.625'
ax1 = df_nh4no3_1.plot(x='freq', y = comp);
df_nano3.plot(x='freq', ax=ax1, y = comp);
